# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/ChrisVelasquez/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/ChrisVelasquez/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

base_url = f"{url}appid={weather_api_key}&units={units}&q="

clouds = []
winds = []
temp = []
humidity = []
country = []
lat = []
lng = []
city_list = []
date = []


print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1

for city in cities:
    
    if record_count > 10:
        record_count = 1
        set_count += 1
        
    else:
        record_count += 1
        
    try:
        city_url = f'{base_url}{city.replace(" ", "+")}'
        response = requests.get(city_url)
        print(f"Processing Record Number {record_count} of Set Number {set_count} | City of {city}")  
        print(city_url)
    
        data = response.json()
        time.sleep(1)
        clouds.append(data["clouds"]["all"])
        winds.append(data["wind"]["speed"])
        temp.append(data["main"]["temp_max"])
        humidity.append(data["main"]["humidity"])
        country.append(data["sys"]["country"])
        lat.append(data["coord"]["lat"])
        lng.append(data["coord"]["lon"])
        date.append(data["dt"])
        city_list.append(city)
    
    except:
        print("City not found. Onto the next one...")
        
print("------------Data Retrieval Complete.------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record Number 2 of Set Number 1 | City of butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=butaritari
# Processing Record Number 3 of Set Number 1 | City of preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=preobrazheniye
# Processing Record Number 4 of Set Number 1 | City of avarua
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=avarua
# Processing Record Number 5 of Set Number 1 | City of kahului
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kahului
# Processing Record Number 6 of Set Number 1 | City of attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=attawapiskat
# City not found. Onto the next one...
# Processing Record Number 7 of Set Number 1 | City of rawson
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=rawson
# Processing Record Number 8 of Set Number 1 | City of vaini
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=vaini
# Processing Record Number 9 of Set Number 1 | City of faya
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=faya
# Processing Record Number 10 of Set Number 1 | City of port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=port+elizabeth
# Processing Record Number 11 of Set Number 1 | City of dunmore town
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=dunmore+town
# Processing Record Number 1 of Set Number 2 | City of sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sinnamary
# Processing Record Number 2 of Set Number 2 | City of port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=port+alfred
# Processing Record Number 3 of Set Number 2 | City of yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=yar-sale
# Processing Record Number 4 of Set Number 2 | City of ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ushuaia
# Processing Record Number 5 of Set Number 2 | City of georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=georgetown
# Processing Record Number 6 of Set Number 2 | City of kosonsoy
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kosonsoy
# Processing Record Number 7 of Set Number 2 | City of upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=upernavik
# Processing Record Number 8 of Set Number 2 | City of tevaitoa
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tevaitoa
# Processing Record Number 9 of Set Number 2 | City of albany
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=albany
# Processing Record Number 10 of Set Number 2 | City of port hueneme
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=port+hueneme
# Processing Record Number 11 of Set Number 2 | City of westlock
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=westlock
# Processing Record Number 1 of Set Number 3 | City of bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bambous+virieux
# Processing Record Number 2 of Set Number 3 | City of barrow
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=barrow
# Processing Record Number 3 of Set Number 3 | City of puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=puerto+ayora
# Processing Record Number 4 of Set Number 3 | City of rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=rikitea
# Processing Record Number 5 of Set Number 3 | City of khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=khatanga
# Processing Record Number 6 of Set Number 3 | City of bluff
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bluff
# Processing Record Number 7 of Set Number 3 | City of rafsanjan
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=rafsanjan
# Processing Record Number 8 of Set Number 3 | City of punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=punta+arenas
# Processing Record Number 9 of Set Number 3 | City of busselton
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=busselton
# Processing Record Number 10 of Set Number 3 | City of ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ketchikan
# Processing Record Number 11 of Set Number 3 | City of branesti
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=branesti
# Processing Record Number 1 of Set Number 4 | City of taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=taolanaro
# City not found. Onto the next one...
# Processing Record Number 2 of Set Number 4 | City of tadine
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tadine
# Processing Record Number 3 of Set Number 4 | City of kegayli
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kegayli
# City not found. Onto the next one...
# Processing Record Number 4 of Set Number 4 | City of puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=puerto+del+rosario
# Processing Record Number 5 of Set Number 4 | City of kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kapaa
# Processing Record Number 6 of Set Number 4 | City of souillac
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=souillac
# Processing Record Number 7 of Set Number 4 | City of cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cherskiy
# Processing Record Number 8 of Set Number 4 | City of izumo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=izumo
# Processing Record Number 9 of Set Number 4 | City of damietta
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=damietta
# Processing Record Number 10 of Set Number 4 | City of mataura
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mataura
# Processing Record Number 11 of Set Number 4 | City of luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=luderitz
# Processing Record Number 1 of Set Number 5 | City of kaeo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kaeo
# Processing Record Number 2 of Set Number 5 | City of erzin
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=erzin
# Processing Record Number 3 of Set Number 5 | City of cortez
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cortez
# Processing Record Number 4 of Set Number 5 | City of umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=umzimvubu
# City not found. Onto the next one...
# Processing Record Number 5 of Set Number 5 | City of manokwari
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=manokwari
# Processing Record Number 6 of Set Number 5 | City of malkapur
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=malkapur
# Processing Record Number 7 of Set Number 5 | City of grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=grindavik
# Processing Record Number 8 of Set Number 5 | City of beira
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=beira
# Processing Record Number 9 of Set Number 5 | City of hailey
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hailey
# Processing Record Number 10 of Set Number 5 | City of bokoro
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bokoro
# Processing Record Number 11 of Set Number 5 | City of qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=qaanaaq
# Processing Record Number 1 of Set Number 6 | City of carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=carnarvon
# Processing Record Number 2 of Set Number 6 | City of lasa
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=lasa
# Processing Record Number 3 of Set Number 6 | City of san jose
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=san+jose
# Processing Record Number 4 of Set Number 6 | City of pisco
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=pisco
# Processing Record Number 5 of Set Number 6 | City of along
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=along
# Processing Record Number 6 of Set Number 6 | City of cape town
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cape+town
# Processing Record Number 7 of Set Number 6 | City of sunnyside
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sunnyside
# Processing Record Number 8 of Set Number 6 | City of boddam
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=boddam
# Processing Record Number 9 of Set Number 6 | City of barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=barentsburg
# City not found. Onto the next one...
# Processing Record Number 10 of Set Number 6 | City of hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hualmay
# Processing Record Number 11 of Set Number 6 | City of pevek
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=pevek
# Processing Record Number 1 of Set Number 7 | City of kostino
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kostino
# Processing Record Number 2 of Set Number 7 | City of tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tasiilaq
# Processing Record Number 3 of Set Number 7 | City of husavik
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=husavik
# Processing Record Number 4 of Set Number 7 | City of constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=constitucion
# Processing Record Number 5 of Set Number 7 | City of port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=port+hardy
# Processing Record Number 6 of Set Number 7 | City of loiza
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=loiza
# Processing Record Number 7 of Set Number 7 | City of castro
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=castro
# Processing Record Number 8 of Set Number 7 | City of puerto madryn
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=puerto+madryn
# Processing Record Number 9 of Set Number 7 | City of fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=fort+nelson
# Processing Record Number 10 of Set Number 7 | City of dikson
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=dikson
# Processing Record Number 11 of Set Number 7 | City of kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kysyl-syr
# Processing Record Number 1 of Set Number 8 | City of cocobeach
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cocobeach
# Processing Record Number 2 of Set Number 8 | City of satitoa
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=satitoa
# City not found. Onto the next one...
# Processing Record Number 3 of Set Number 8 | City of hobart
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hobart
# Processing Record Number 4 of Set Number 8 | City of kailua
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kailua
# Processing Record Number 5 of Set Number 8 | City of new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=new+norfolk
# Processing Record Number 6 of Set Number 8 | City of abnub
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=abnub
# Processing Record Number 7 of Set Number 8 | City of amderma
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=amderma
# City not found. Onto the next one...
# Processing Record Number 8 of Set Number 8 | City of iskateley
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=iskateley
# Processing Record Number 9 of Set Number 8 | City of hilo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hilo
# Processing Record Number 10 of Set Number 8 | City of airai
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=airai
# Processing Record Number 11 of Set Number 8 | City of sturgis
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sturgis
# Processing Record Number 1 of Set Number 9 | City of narimanov
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=narimanov
# Processing Record Number 2 of Set Number 9 | City of medea
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=medea
# Processing Record Number 3 of Set Number 9 | City of hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hithadhoo
# Processing Record Number 4 of Set Number 9 | City of pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=pangnirtung
# Processing Record Number 5 of Set Number 9 | City of sars
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sars
# Processing Record Number 6 of Set Number 9 | City of tabuk
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tabuk
# Processing Record Number 7 of Set Number 9 | City of porbandar
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=porbandar
# Processing Record Number 8 of Set Number 9 | City of marcona
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=marcona
# City not found. Onto the next one...
# Processing Record Number 9 of Set Number 9 | City of uvalde
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=uvalde
# Processing Record Number 10 of Set Number 9 | City of halifax
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=halifax
# Processing Record Number 11 of Set Number 9 | City of severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=severo-kurilsk
# Processing Record Number 1 of Set Number 10 | City of giyani
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=giyani
# Processing Record Number 2 of Set Number 10 | City of quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=quatre+cocos
# Processing Record Number 3 of Set Number 10 | City of belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=belushya+guba
# City not found. Onto the next one...
# Processing Record Number 4 of Set Number 10 | City of kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kodiak
# Processing Record Number 5 of Set Number 10 | City of talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=talnakh
# Processing Record Number 6 of Set Number 10 | City of inuvik
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=inuvik
# Processing Record Number 7 of Set Number 10 | City of pimentel
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=pimentel
# Processing Record Number 8 of Set Number 10 | City of yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=yellowknife
# Processing Record Number 9 of Set Number 10 | City of mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mar+del+plata
# Processing Record Number 10 of Set Number 10 | City of palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=palabuhanratu
# City not found. Onto the next one...
# Processing Record Number 11 of Set Number 10 | City of jizan
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=jizan
# Processing Record Number 1 of Set Number 11 | City of srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=srednekolymsk
# Processing Record Number 2 of Set Number 11 | City of valdosta
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=valdosta
# Processing Record Number 3 of Set Number 11 | City of maraba
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=maraba
# Processing Record Number 4 of Set Number 11 | City of rongu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=rongu
# City not found. Onto the next one...
# Processing Record Number 5 of Set Number 11 | City of ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ribeira+grande
# Processing Record Number 6 of Set Number 11 | City of kabare
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kabare
# Processing Record Number 7 of Set Number 11 | City of jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=jamestown
# Processing Record Number 8 of Set Number 11 | City of igrim
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=igrim
# Processing Record Number 9 of Set Number 11 | City of ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ngukurr
# City not found. Onto the next one...
# Processing Record Number 10 of Set Number 11 | City of atuona
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=atuona
# Processing Record Number 11 of Set Number 11 | City of namibe
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=namibe
# Processing Record Number 1 of Set Number 12 | City of isangel
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=isangel
# Processing Record Number 2 of Set Number 12 | City of north bend
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=north+bend
# Processing Record Number 3 of Set Number 12 | City of brooks
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=brooks
# Processing Record Number 4 of Set Number 12 | City of illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=illoqqortoormiut
# City not found. Onto the next one...
# Processing Record Number 5 of Set Number 12 | City of victoria
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=victoria
# Processing Record Number 6 of Set Number 12 | City of senador pompeu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=senador+pompeu
# Processing Record Number 7 of Set Number 12 | City of nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nizhniy+kuranakh
# Processing Record Number 8 of Set Number 12 | City of vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=vila+franca+do+campo
# Processing Record Number 9 of Set Number 12 | City of muros
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=muros
# Processing Record Number 10 of Set Number 12 | City of vila do maio
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=vila+do+maio
# Processing Record Number 11 of Set Number 12 | City of korla
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=korla
# Processing Record Number 1 of Set Number 13 | City of trairi
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=trairi
# Processing Record Number 2 of Set Number 13 | City of samusu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=samusu
# City not found. Onto the next one...
# Processing Record Number 3 of Set Number 13 | City of kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kavaratti
# Processing Record Number 4 of Set Number 13 | City of bagrami
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bagrami
# Processing Record Number 5 of Set Number 13 | City of novi sanzhary
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=novi+sanzhary
# Processing Record Number 6 of Set Number 13 | City of petrolina
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=petrolina
# Processing Record Number 7 of Set Number 13 | City of carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=carutapera
# Processing Record Number 8 of Set Number 13 | City of padang
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=padang
# Processing Record Number 9 of Set Number 13 | City of menongue
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=menongue
# Processing Record Number 10 of Set Number 13 | City of lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=lompoc
# Processing Record Number 11 of Set Number 13 | City of tiarei
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tiarei
# Processing Record Number 1 of Set Number 14 | City of mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mys+shmidta
# City not found. Onto the next one...
# Processing Record Number 2 of Set Number 14 | City of cravo norte
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cravo+norte
# Processing Record Number 3 of Set Number 14 | City of cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cabo+san+lucas
# Processing Record Number 4 of Set Number 14 | City of bontang
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bontang
# Processing Record Number 5 of Set Number 14 | City of palmer
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=palmer
# Processing Record Number 6 of Set Number 14 | City of chuy
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=chuy
# Processing Record Number 7 of Set Number 14 | City of oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=oranjemund
# Processing Record Number 8 of Set Number 14 | City of hinesville
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hinesville
# Processing Record Number 9 of Set Number 14 | City of te anau
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=te+anau
# Processing Record Number 10 of Set Number 14 | City of longyan
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=longyan
# Processing Record Number 11 of Set Number 14 | City of dinajpur
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=dinajpur
# Processing Record Number 1 of Set Number 15 | City of lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=lavrentiya
# Processing Record Number 2 of Set Number 15 | City of hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hobyo
# Processing Record Number 3 of Set Number 15 | City of nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nikolskoye
# Processing Record Number 4 of Set Number 15 | City of tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tiksi
# Processing Record Number 5 of Set Number 15 | City of vao
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=vao
# Processing Record Number 6 of Set Number 15 | City of burley
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=burley
# Processing Record Number 7 of Set Number 15 | City of tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tuktoyaktuk
# Processing Record Number 8 of Set Number 15 | City of cherkasskoye
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cherkasskoye
# Processing Record Number 9 of Set Number 15 | City of nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nanortalik
# Processing Record Number 10 of Set Number 15 | City of arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=arraial+do+cabo
# Processing Record Number 11 of Set Number 15 | City of naze
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=naze
# Processing Record Number 1 of Set Number 16 | City of jackson
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=jackson
# Processing Record Number 2 of Set Number 16 | City of sidi ali
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sidi+ali
# Processing Record Number 3 of Set Number 16 | City of lardos
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=lardos
# Processing Record Number 4 of Set Number 16 | City of kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kavieng
# Processing Record Number 5 of Set Number 16 | City of lebu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=lebu
# Processing Record Number 6 of Set Number 16 | City of ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ponta+delgada
# Processing Record Number 7 of Set Number 16 | City of portland
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=portland
# Processing Record Number 8 of Set Number 16 | City of hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hermanus
# Processing Record Number 9 of Set Number 16 | City of dingle
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=dingle
# Processing Record Number 10 of Set Number 16 | City of berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=berlevag
# Processing Record Number 11 of Set Number 16 | City of thompson
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=thompson
# Processing Record Number 1 of Set Number 17 | City of ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ponta+do+sol
# Processing Record Number 2 of Set Number 17 | City of grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=grand+river+south+east
# City not found. Onto the next one...
# Processing Record Number 3 of Set Number 17 | City of aksu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=aksu
# Processing Record Number 4 of Set Number 17 | City of faanui
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=faanui
# Processing Record Number 5 of Set Number 17 | City of vardo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=vardo
# Processing Record Number 6 of Set Number 17 | City of longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=longyearbyen
# Processing Record Number 7 of Set Number 17 | City of port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=port+lincoln
# Processing Record Number 8 of Set Number 17 | City of myre
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=myre
# Processing Record Number 9 of Set Number 17 | City of kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kruisfontein
# Processing Record Number 10 of Set Number 17 | City of tura
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tura
# Processing Record Number 11 of Set Number 17 | City of beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=beringovskiy
# Processing Record Number 1 of Set Number 18 | City of bowen
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bowen
# Processing Record Number 2 of Set Number 18 | City of mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mahebourg
# Processing Record Number 3 of Set Number 18 | City of bethel
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bethel
# Processing Record Number 4 of Set Number 18 | City of lumajang
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=lumajang
# Processing Record Number 5 of Set Number 18 | City of saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=saint-philippe
# Processing Record Number 6 of Set Number 18 | City of norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=norman+wells
# Processing Record Number 7 of Set Number 18 | City of sao miguel do araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sao+miguel+do+araguaia
# Processing Record Number 8 of Set Number 18 | City of vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=vanimo
# Processing Record Number 9 of Set Number 18 | City of concepcion del norte
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=concepcion+del+norte
# City not found. Onto the next one...
# Processing Record Number 10 of Set Number 18 | City of methven
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=methven
# Processing Record Number 11 of Set Number 18 | City of saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=saskylakh
# Processing Record Number 1 of Set Number 19 | City of cochrane
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cochrane
# Processing Record Number 2 of Set Number 19 | City of irbeyskoye
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=irbeyskoye
# Processing Record Number 3 of Set Number 19 | City of bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bathsheba
# Processing Record Number 4 of Set Number 19 | City of provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=provideniya
# Processing Record Number 5 of Set Number 19 | City of kinshasa
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kinshasa
# Processing Record Number 6 of Set Number 19 | City of hirara
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hirara
# Processing Record Number 7 of Set Number 19 | City of iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=iqaluit
# Processing Record Number 8 of Set Number 19 | City of muzhi
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=muzhi
# Processing Record Number 9 of Set Number 19 | City of dongning
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=dongning
# Processing Record Number 10 of Set Number 19 | City of hovd
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hovd
# Processing Record Number 11 of Set Number 19 | City of mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mitsamiouli
# Processing Record Number 1 of Set Number 20 | City of awbari
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=awbari
# Processing Record Number 2 of Set Number 20 | City of hounde
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hounde
# Processing Record Number 3 of Set Number 20 | City of east london
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=east+london
# Processing Record Number 4 of Set Number 20 | City of ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ilulissat
# Processing Record Number 5 of Set Number 20 | City of laem sing
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=laem+sing
# Processing Record Number 6 of Set Number 20 | City of kidal
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kidal
# Processing Record Number 7 of Set Number 20 | City of sorland
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sorland
# Processing Record Number 8 of Set Number 20 | City of ordzhonikidze
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ordzhonikidze
# Processing Record Number 9 of Set Number 20 | City of bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bredasdorp
# Processing Record Number 10 of Set Number 20 | City of nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nyurba
# Processing Record Number 11 of Set Number 20 | City of anar darreh
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=anar+darreh
# City not found. Onto the next one...
# Processing Record Number 1 of Set Number 21 | City of pangoa
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=pangoa
# Processing Record Number 2 of Set Number 21 | City of chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=chokurdakh
# Processing Record Number 3 of Set Number 21 | City of fulitun
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=fulitun
# City not found. Onto the next one...
# Processing Record Number 4 of Set Number 21 | City of san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=san+quintin
# Processing Record Number 5 of Set Number 21 | City of karratha
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=karratha
# Processing Record Number 6 of Set Number 21 | City of pahrump
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=pahrump
# Processing Record Number 7 of Set Number 21 | City of mudanjiang
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mudanjiang
# Processing Record Number 8 of Set Number 21 | City of broome
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=broome
# Processing Record Number 9 of Set Number 21 | City of monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=monrovia
# Processing Record Number 10 of Set Number 21 | City of touros
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=touros
# Processing Record Number 11 of Set Number 21 | City of tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tuatapere
# Processing Record Number 1 of Set Number 22 | City of nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nizhneyansk
# City not found. Onto the next one...
# Processing Record Number 2 of Set Number 22 | City of cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cockburn+town
# Processing Record Number 3 of Set Number 22 | City of antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=antofagasta
# Processing Record Number 4 of Set Number 22 | City of hornepayne
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hornepayne
# Processing Record Number 5 of Set Number 22 | City of teya
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=teya
# City not found. Onto the next one...
# Processing Record Number 7 of Set Number 22 | City of bilma
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bilma
# Processing Record Number 8 of Set Number 22 | City of agirish
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=agirish
# Processing Record Number 9 of Set Number 22 | City of saint-denis
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=saint-denis
# Processing Record Number 10 of Set Number 22 | City of marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=marsh+harbour
# Processing Record Number 11 of Set Number 22 | City of huntsville
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=huntsville
# Processing Record Number 1 of Set Number 23 | City of tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tsihombe
# City not found. Onto the next one...
# Processing Record Number 2 of Set Number 23 | City of ibanda
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ibanda
# Processing Record Number 3 of Set Number 23 | City of batangafo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=batangafo
# Processing Record Number 4 of Set Number 23 | City of bonfim
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bonfim
# Processing Record Number 5 of Set Number 23 | City of viedma
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=viedma
# Processing Record Number 6 of Set Number 23 | City of palanpur
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=palanpur
# Processing Record Number 7 of Set Number 23 | City of kalmar
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kalmar
# Processing Record Number 8 of Set Number 23 | City of atambua
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=atambua
# Processing Record Number 9 of Set Number 23 | City of alakurtti
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=alakurtti
# Processing Record Number 10 of Set Number 23 | City of jalu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=jalu
# Processing Record Number 11 of Set Number 23 | City of aginskoye
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=aginskoye
# Processing Record Number 1 of Set Number 24 | City of pitimbu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=pitimbu
# Processing Record Number 2 of Set Number 24 | City of quzhou
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=quzhou
# Processing Record Number 3 of Set Number 24 | City of armacao dos buzios
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=armacao+dos+buzios
# City not found. Onto the next one...
# Processing Record Number 4 of Set Number 24 | City of westpunt
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=westpunt
# City not found. Onto the next one...
# Processing Record Number 5 of Set Number 24 | City of waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=waingapu
# Processing Record Number 6 of Set Number 24 | City of clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=clyde+river
# Processing Record Number 7 of Set Number 24 | City of cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cap+malheureux
# Processing Record Number 8 of Set Number 24 | City of acurenam
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=acurenam
# Processing Record Number 9 of Set Number 24 | City of piacabucu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=piacabucu
# Processing Record Number 10 of Set Number 24 | City of fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=fortuna
# Processing Record Number 11 of Set Number 24 | City of smithers
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=smithers
# Processing Record Number 1 of Set Number 25 | City of coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=coahuayana
# Processing Record Number 2 of Set Number 25 | City of bogalusa
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bogalusa
# Processing Record Number 3 of Set Number 25 | City of nago
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nago
# Processing Record Number 4 of Set Number 25 | City of chernolesskoye
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=chernolesskoye
# Processing Record Number 5 of Set Number 25 | City of mnisek pod brdy
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mnisek+pod+brdy
# City not found. Onto the next one...
# Processing Record Number 7 of Set Number 25 | City of havelock
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=havelock
# Processing Record Number 8 of Set Number 25 | City of baie-comeau
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=baie-comeau
# Processing Record Number 9 of Set Number 25 | City of nikolayevka
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nikolayevka
# Processing Record Number 10 of Set Number 25 | City of mlonggo
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=guerrero+negro
# Processing Record Number 7 of Set Number 49 | City of proddatur
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=proddatur
# Processing Record Number 8 of Set Number 49 | City of oda
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=oda
# Processing Record Number 9 of Set Number 49 | City of salice salentino
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=salice+salentino
# Processing Record Number 10 of Set Number 49 | City of avera
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=avera
# Processing Record Number 11 of Set Number 49 | City of biskamzha
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=biskamzha
# Processing Record Number 1 of Set Number 50 | City of tamasopo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tamasopo
# Processing Record Number 2 of Set Number 50 | City of swedru
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=swedru
# Processing Record Number 3 of Set Number 50 | City of wasilla
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=wasilla
# Processing Record Number 4 of Set Number 50 | City of severnoye
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=severnoye
# Processing Record Number 5 of Set Number 50 | City of khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=khandyga
# Processing Record Number 6 of Set Number 50 | City of mugreyevskiy
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mugreyevskiy
# City not found. Onto the next one...
# Processing Record Number 7 of Set Number 50 | City of katherine
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=katherine
# Processing Record Number 8 of Set Number 50 | City of rawannawi
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=rawannawi
# City not found. Onto the next one...
# Processing Record Number 9 of Set Number 50 | City of melito di porto salvo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=melito+di+porto+salvo
# Processing Record Number 10 of Set Number 50 | City of general pico
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=general+pico
# Processing Record Number 11 of Set Number 50 | City of falealupo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=falealupo
# City not found. Onto the next one...
# Processing Record Number 1 of Set Number 51 | City of coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=coquimbo
# Processing Record Number 2 of Set Number 51 | City of colares
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=colares
# Processing Record Number 3 of Set Number 51 | City of west helena
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=west+helena
# Processing Record Number 4 of Set Number 51 | City of boyolangu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=boyolangu
# Processing Record Number 5 of Set Number 51 | City of kaseda
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kaseda
# Processing Record Number 6 of Set Number 51 | City of goderich
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=goderich
# Processing Record Number 7 of Set Number 51 | City of galiwinku
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=galiwinku
# City not found. Onto the next one...
# Processing Record Number 8 of Set Number 51 | City of campbeltown
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=campbeltown
# Processing Record Number 9 of Set Number 51 | City of kyaiklat
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kyaiklat
# Processing Record Number 10 of Set Number 51 | City of udachnyy
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=udachnyy
# Processing Record Number 11 of Set Number 51 | City of velika obarska
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=velika+obarska
# Processing Record Number 1 of Set Number 52 | City of kamaishi
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=kamaishi
# Processing Record Number 2 of Set Number 52 | City of paradwip
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=paradwip
# City not found. Onto the next one...
# Processing Record Number 3 of Set Number 52 | City of nuevitas
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nuevitas
# Processing Record Number 4 of Set Number 52 | City of muriti
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=muriti
# Processing Record Number 5 of Set Number 52 | City of muscat
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=muscat
# Processing Record Number 6 of Set Number 52 | City of parker
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=parker
# Processing Record Number 7 of Set Number 52 | City of chokwe
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=chokwe
# Processing Record Number 8 of Set Number 52 | City of mizdah
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mizdah
# Processing Record Number 9 of Set Number 52 | City of lubango
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=lubango
# Processing Record Number 10 of Set Number 52 | City of chagda
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=chagda
# City not found. Onto the next one...
# Processing Record Number 11 of Set Number 52 | City of bargal
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bargal
# City not found. Onto the next one...
# Processing Record Number 1 of Set Number 53 | City of cumra
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cumra
# Processing Record Number 2 of Set Number 53 | City of muisne
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=muisne
# Processing Record Number 3 of Set Number 53 | City of nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=nouadhibou
# Processing Record Number 4 of Set Number 53 | City of san pedro
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=san+pedro
# Processing Record Number 5 of Set Number 53 | City of fez
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=fez
# Processing Record Number 6 of Set Number 53 | City of rolim de moura
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=rolim+de+moura
# City not found. Onto the next one...
# Processing Record Number 7 of Set Number 53 | City of margate
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=margate
# Processing Record Number 8 of Set Number 53 | City of morant bay
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=morant+bay
# Processing Record Number 9 of Set Number 53 | City of victor harbor
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=victor+harbor
# Processing Record Number 10 of Set Number 53 | City of asilah
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=asilah
# Processing Record Number 11 of Set Number 53 | City of abdanan
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=abdanan
# Processing Record Number 1 of Set Number 54 | City of yemelyanovo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=yemelyanovo
# Processing Record Number 2 of Set Number 54 | City of ajtos
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ajtos
# Processing Record Number 3 of Set Number 54 | City of ormara
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=ormara
# Processing Record Number 4 of Set Number 54 | City of aktas
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=aktas
# Processing Record Number 5 of Set Number 54 | City of hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hambantota
# Processing Record Number 6 of Set Number 54 | City of christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=christchurch
# Processing Record Number 7 of Set Number 54 | City of hunza
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hunza
# City not found. Onto the next one...
# Processing Record Number 8 of Set Number 54 | City of tuban
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tuban
# Processing Record Number 9 of Set Number 54 | City of saint-leu
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=saint-leu
# Processing Record Number 10 of Set Number 54 | City of amahai
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=amahai
# Processing Record Number 11 of Set Number 54 | City of norwich
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=norwich
# Processing Record Number 1 of Set Number 55 | City of lancaster
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=lancaster
# Processing Record Number 2 of Set Number 55 | City of sol-iletsk
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sol-iletsk
# Processing Record Number 3 of Set Number 55 | City of hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=hamilton
# Processing Record Number 4 of Set Number 55 | City of cozumel
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cozumel
# Processing Record Number 5 of Set Number 55 | City of sokolo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sokolo
# Processing Record Number 6 of Set Number 55 | City of palana
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=palana
# Processing Record Number 7 of Set Number 55 | City of yulara
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=yulara
# Processing Record Number 8 of Set Number 55 | City of eydhafushi
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=eydhafushi
# Processing Record Number 9 of Set Number 55 | City of gadsden
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=gadsden
# Processing Record Number 10 of Set Number 55 | City of saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=saint-joseph
# Processing Record Number 11 of Set Number 55 | City of mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mount+isa
# Processing Record Number 1 of Set Number 56 | City of mumford
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mumford
# Processing Record Number 2 of Set Number 56 | City of altay
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=altay
# Processing Record Number 3 of Set Number 56 | City of jinchang
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=jinchang
# Processing Record Number 4 of Set Number 56 | City of mossendjo
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=mossendjo
# Processing Record Number 5 of Set Number 56 | City of bauska
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=bauska
# Processing Record Number 6 of Set Number 56 | City of sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=sungaipenuh
# Processing Record Number 7 of Set Number 56 | City of tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=tiznit
# Processing Record Number 8 of Set Number 56 | City of goudomp
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=goudomp
# City not found. Onto the next one...
# Processing Record Number 9 of Set Number 56 | City of syedove
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=syedove
# Processing Record Number 10 of Set Number 56 | City of elat
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=elat
# Processing Record Number 11 of Set Number 56 | City of eureka
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=eureka
# Processing Record Number 1 of Set Number 57 | City of camacha
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=camacha
# Processing Record Number 2 of Set Number 57 | City of cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=cayenne
# Processing Record Number 3 of Set Number 57 | City of fougeres
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=fougeres
# Processing Record Number 4 of Set Number 57 | City of gaoua
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=gaoua
# Processing Record Number 5 of Set Number 57 | City of new iberia
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=new+iberia
# Processing Record Number 6 of Set Number 57 | City of marrakesh
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=marrakesh
# Processing Record Number 7 of Set Number 57 | City of comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=af63661253f7cf253a9f7e89034bfaa3&units=metric&q=comodoro+rivadavia
# ------------Data Retrieval Complete.------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cityData_pd = pd.DataFrame(cities)
cityData_pd.count()
# Out:
# 0    622
# dtype: int64

# %%
weatherpy = {"City": city_list, "Country": country, "Date": date, "Lat": lat, "Long": lng, "Max Temp": temp, "Humidity": humidity, "Cloudiness": clouds, "Wind Speed": winds}

weatherpy_df = pd.DataFrame(weatherpy)

weatherpy_df.head()
# Out:
#              City Country        Date      Lat      Long  Max Temp  Humidity  \
# 0      butaritari      KI  1630968624   3.0707  172.7902     28.88        71
# 1  preobrazheniye      RU  1630968626  42.9019  133.9064     18.66        77
# 2          avarua      CK  1630968631 -21.2078 -159.7750     25.03        69
# 3         kahului      US  1630968464  20.8947 -156.4700     30.01        58
# 4          rawson      AR  1630968638 -43.3002  -65.1023     13.42        64
#
#    Cloudiness  Wind Speed
# 0         100        5.87
# 1         100        2.87
# 2          75        8.23
# 3          40        9.26
# 4          97        2.49

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
lats = cleanCity_data["Lat"]
maxTemps = cleanCity_data["Max Temp"]
humidity = cleanCity_data["Humidity"]
cloudiness = cleanCity_data["Cloudiness"]
wind_speed = cleanCity_data["Wind Speed"]

cleanCity_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weatherpy_df['Lat'], weatherpy_df['Max Temp'], alpha = 0.75, edgecolors = 'black', linewidths = 1, marker = "o")

plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("City Latitude vs. Max Temperature.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weatherpy_df['Lat'], weatherpy_df['Humidity'], alpha = 0.75, edgecolors = 'black', linewidths = 1, marker = "o")

plt.title("City Latitude vs. Humidity (%s)" % time.strftime ("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("City Latitude vs. Humidity.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weatherpy_df['Lat'], weatherpy_df['Cloudiness'], alpha = 0.75, edgecolors = 'black', linewidths = 1, marker = "o")

plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime ("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weatherpy_df['Lat'], weatherpy_df['Wind Speed'], alpha = 0.75, edgecolors = 'black', linewidths = 1, marker = "o")

plt.title("City Latitude vs. Humidity (%s)" % time.strftime ("%x"))
plt.ylabel("Wind Speed (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("City Latitude vs. Wind Speed.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Linear Regression

# %%
northern_hemisphere = weatherpy_df.loc[(weatherpy_df["Lat"]>=0)]
southern_hemisphere = weatherpy_df.loc[(weatherpy_df["Lat"]<=0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(northern_hemisphere['Lat'], northern_hemisphere['Max Temp'], alpha = 0.75, edgecolors = 'black', linewidths=1, marker="o",)

plt.title('City Latitude vs. Max Temperature (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Max Temperature (C)')
plt.grid(True)

x = northern_hemisphere['Lat']
y = northern_hemisphere['Max Temp'] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 
analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")
plt.annotate(analysis,(0, -10), color = "red", fontsize = 20)
plt.savefig("Linear Regreesion of City Latitude vs. Max Temperature - Nothern Hemisphere.png")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(southern_hemisphere['Lat'], southern_hemisphere['Max Temp'], alpha = 0.75, edgecolors = 'black', linewidths=1, marker="o",)

plt.title('City Latitude vs. Max Temperature (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Max Temperature (C)')
plt.grid(True)

x = southern_hemisphere['Lat']
y = southern_hemisphere['Max Temp'] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 
analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")
plt.annotate(analysis,(-30, 5), color = "red", fontsize = 20)
plt.savefig("Linear Regreesion of City Latitude vs. Max Temperature - Southern Hemisphere.png")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_hemisphere['Lat'], northern_hemisphere['Humidity'], alpha = 0.75, edgecolors = 'black', linewidths=1, marker="o",)

plt.title('City Latitude vs. Humidity (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Humdity')
plt.grid(True)

x = northern_hemisphere['Lat']
y = northern_hemisphere['Humidity'] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 
analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")
plt.annotate(analysis,(40, 40), color = "red", fontsize = 20)
plt.savefig("Linear Regreesion of City Latitude vs. Humidity - Nothern Hemisphere.png")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_hemisphere['Lat'], southern_hemisphere['Humidity'], alpha = 0.75, edgecolors = 'black', linewidths=1, marker="o",)

plt.title('City Latitude vs. Humidity (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Humdity')
plt.grid(True)

x = southern_hemisphere['Lat']
y = southern_hemisphere['Humidity'] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 
analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")
plt.annotate(analysis,(-50, 40), color = "red", fontsize = 20)
plt.savefig("Linear Regreesion of City Latitude vs. Humidity - Southern Hemisphere.png")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_hemisphere['Lat'], northern_hemisphere['Cloudiness'], alpha = 0.75, edgecolors = 'black', linewidths=1, marker="o",)

plt.title('City Latitude vs. Cloudiness (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Humdity')
plt.grid(True)

x = northern_hemisphere['Lat']
y = northern_hemisphere['Cloudiness'] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 
analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")
plt.annotate(analysis,(40, 40), color = "red", fontsize = 20)
plt.savefig("Linear Regreesion of City Latitude vs. Cloudiness - Nothern Hemisphere.png")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_hemisphere['Lat'], southern_hemisphere['Cloudiness'], alpha = 0.75, edgecolors = 'black', linewidths=1, marker="o",)

plt.title('City Latitude vs. Cloudiness (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Humdity')
plt.grid(True)

x = southern_hemisphere['Lat']
y = southern_hemisphere['Cloudiness'] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 
analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")
plt.annotate(analysis,(-50, 40), color = "red", fontsize = 20)
plt.savefig("Linear Regreesion of City Latitude vs. Cloudiness - Southern Hemisphere.png")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(northern_hemisphere['Lat'], northern_hemisphere['Wind Speed'], alpha = 0.75, edgecolors = 'black', linewidths=1, marker="o",)

plt.title('City Latitude vs. Wind Speed (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Wind Speed')
plt.grid(True)

x = northern_hemisphere['Lat']
y = northern_hemisphere['Wind Speed'] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 
analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")
plt.annotate(analysis,(0, 12), color = "red", fontsize = 20)
plt.savefig("Linear Regreesion of City Latitude vs. Wind Speed - Nothern Hemisphere.png")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(southern_hemisphere['Lat'], southern_hemisphere['Wind Speed'], alpha = 0.75, edgecolors = 'black', linewidths=1, marker="o",)

plt.title('City Latitude vs. Wind Speed (%s)' % time.strftime('%x'))
plt.xlabel('Latitude') 
plt.ylabel('Wind Speed')
plt.grid(True)

x = southern_hemisphere['Lat']
y = southern_hemisphere['Wind Speed'] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

regress_value = x * slope + intercept 
analysis = (f"y = {str(round(slope, 2))}x + {str(round(intercept, 2))}")

plt.plot(x, regress_value, "r-")
plt.annotate(analysis,(-50, 6), color = "red", fontsize = 20)
plt.savefig("Linear Regreesion of City Latitude vs. Wind Speed - Southern Hemisphere.png")

plt.show()

# %%
weatherpy_df.to_csv("../cities_weather.csv")
